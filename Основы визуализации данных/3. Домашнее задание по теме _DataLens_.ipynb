# %% [markdown]
# **Домашнее задание по теме "DataLens"**
#
# Давайте подведём итоги. Мы взялись за первую и очень важную задачу для ритейл-сети — определились с местом размещения её новой точки. В этом нам помог облачный сервис Yandex DataLens. Мы построили удобную карту, визуализировали нужные данные по имеющимся точкам и определились с потенциальной новой.
#
# В рамках ДЗ вам нужно будет развить полученный дашборд, добавив по инструкции следующее:
#
# чарты-индикаторы с ключевыми метриками;
# круговую диаграмму;
# сводную таблицу;
# публичную общедоступную ссылку.

# %% [markdown]
# **Решение:** https://datalens.yandex.cloud/fhnls9riozcu3-dashbord-po-prodazham-magazinov
