# %% [markdown]
# ##**Итоговый проект по курсу "SQL и получение данных"**
#
# **Задание:**
#
# Если вы сталкиваетесь со сложностями, задавайте вопросы нашим экспертам и аспирантам, они с удовольствием вам помогут. Успехов в решении заданий!
#
# Ссылка на итоговый проект https://letsdocode.ru/sql-main/total?utm_referrer=https%3A%2F%2Fnetology.ru%2F
#
# Ссылка на описание БД https://edu.postgrespro.ru/bookings.pdf
#
# Скачать backup файл БД авиаперевозок

# %% [markdown]
# **Решение:**https://drive.google.com/file/d/1Zc20-fzQDgiDsWfXIroykm7UmtAJQSRM/view?usp=drive_link
