# %% [markdown]
# ##**Домашнее задание по теме "Мотивация и технологии работы с большими данными"**
#
# **Задание:**
#
# Проработайте модель данных (основные таблицы и их атрибуты) для хранилища данных (схема «звезда») для любого кейса.
#
# Результат должен содержать:
#
# таблицу фактов (описание того, что там лежит, + столбцы);
# 3-4 таблицы измерений (описание того, что там лежит, + столбцы).
# Оформите результат в виде Google Документа или ER-диаграммы с комментариями.

# %% [markdown]
# **Решение:** https://lucid.app/lucidchart/2a640562-9642-44e4-9d7c-df45b636a03d/edit?viewport_loc=-3301%2C-1551%2C4116%2C1676%2C0_0&invitationId=inv_8694d4b8-f4f4-4232-80c5-4a68ab582414
