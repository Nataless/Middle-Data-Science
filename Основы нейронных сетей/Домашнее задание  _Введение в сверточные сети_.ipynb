# %% [markdown]
# ##**Домашнее задание  "Введение в сверточные сети"**
#
# **Задание:** в отдельном файле.
#
# Здесь вам предстоит построить и обучить свою первую свёрточную сеть для классификации изображений на данных CIFAR10.

# %% [markdown]
# **Решение:**

# %% [markdown]
# ## Данные
#
# CIFAR10
# * 60000 RGB изображений размером 32x32x3
# * 10 классов: самолёты, собаки, рыбы и т.п.
#
# <img src="https://www.samyzaf.com/ML/cifar10/cifar1.jpg" style="width:60%">

# %% [markdown]
# Загрузите данные, разделите их на обучающую и тестовую выборки. Размер тестовой выборки должен быть $10^4$.

# %%
import numpy as np
from tensorflow.keras import layers, models, Input
from tensorflow.keras.datasets import cifar10

# Загрузка данных
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 12s 0us/step

# %% [markdown]
# Создание валидационного и обучающего наборов

# %%
from sklearn.model_selection import train_test_split

# Создаем валидационную выборку из обучающего набора
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Проверка размеров после разделения
print("Размер обучающего набора:", x_train.shape[0])  # Ожидаем 40,000
print("Размер валидационного набора:", x_val.shape[0])  # Ожидаем 10,000
print("Размер тестового набора:", x_test.shape[0])      # Ожидаем 10,000
# Out:
# Размер обучающего набора: 40000
# Размер валидационного набора: 10000
# Размер тестового набора: 10000

# %% [markdown]
# Прежде чем приступать к основной работе, стоит убедиться что загруженно именно то, что требовалось:

# %%
import matplotlib.pyplot as plt

# Список классов CIFAR-10
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Функция для отображения изображений
def plot_images(images, labels, class_names, n=10):
    plt.figure(figsize=(15, 6))
    for i in range(n):
        plt.subplot(2, 5, i+1)
        plt.imshow(images[i])
        plt.title(class_names[labels[i][0]])  # labels[i][0] потому что y_train имеет форму (n, 1)
        plt.axis('off')
    plt.show()

# Отобразим первые 10 изображений из обучающего набора
plot_images(x_train, y_train, class_names)

# %% [markdown]
# ## Подготовка данных
#
# Сейчас каждый пиксель изображения закодирован тройкой чисел (RGB) __от 0 до 255__. Однако лучше себя показывает подход, где значения входов нейросети распределены недалеко от 0.
#
# Давайте приведём все данные в диапазон __`[0, 1]`__ — просто разделим на соответствующий коэффициент:

# %%
# Нормализация данных
x_train = x_train / 255
x_val = x_val / 255
x_test = x_test / 255

# %% [markdown]
# Исполните код ниже для проверки, что все выполнено корректно.

# %%
assert np.shape(x_train) == (40000, 32, 32, 3), "data shape should not change"
assert 0.9 <= max(map(np.max, (x_train, x_val, x_test))) <= 1.05
assert 0.0 <= min(map(np.min, (x_train, x_val, x_test))) <= 0.1
assert len(np.unique(x_test / 255.)) > 10, "make sure you casted data to float type"

# %% [markdown]
# ## Архитектура сети
#
# Для начала реализуйте простую нейросеть:
# 1. принимает на вход картинки размера 32 x 32 x 3;
# 2. вытягивает их в вектор (`keras.layers.Flatten`);
# 3. пропускает через 1 или 2 полносвязных слоя;
# 4. выходной слой отдает вероятности принадлежности к каждому из 10 классов.

# %% [markdown]
# Создайте полносвязную сеть:

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# Создание модели
model = models.Sequential([
    Input(shape=(32, 32, 3)),                   # Входной слой
    layers.Flatten(),                            # Преобразование изображения в вектор
    layers.Dense(128, activation='relu'),       # Первый полносвязный слой
    layers.Dense(64, activation='relu'),        # Второй полносвязный слой
    layers.Dense(10, activation='softmax')      # Выходной слой с 10 классами
])

# Компиляция модели с использованием SGD
model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Вывод структуры модели
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         393,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 402,250 (1.53 MB)
#  Trainable params: 402,250 (1.53 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Обучение сети

# %% [markdown]
# ### **Задание 1.1 (обязательно)**
#
# Будем минимизировать многоклассовую кроссэкнропию с помощью __sgd__. Вам нужно получить сеть, которая достигнет __не менее 45%__ __accuracy__ на тестовых данных.
#
# __Важно:__
#
# поскольку в y_train лежат номера классов, Керасу нужно либо указать sparse функции потерь и метрики оценки качества классификации (`sparse_categorical_crossentropy` и `sparse_categorical_accuracy`), либо конвертировать метки в one-hot формат.
#
# ### Полезные советы
# * `model.compile` позволяет указать, какие метрики вы хотите вычислять.
# * В `model.fit` можно передать валидационную выборку (`validation_data=[X_val, y_val]`), для отслеживания прогресса на ней. Также рекомендуем сохранять результаты в [tensorboard](https://keras.io/callbacks/#tensorboard) или [wandb](https://docs.wandb.ai/integrations/jupyter). **Важно: логи tensorboard не получится без боли посмотреть через colab.** Workaround: скачать логи и запустить tensorboard локально или помучаться [с этим](https://stackoverflow.com/questions/47818822/can-i-use-tensorboard-with-google-colab).
# * По умолчанию сеть учится 1 эпоху. Совсем не факт, что вам этого хватит. Число эпох можно настроить в методе `fit` (`epochs`).
# * Ещё у Кераса есть много [полезных callback-ов](https://keras.io/callbacks/), которые можно попробовать. Например, автоматическая остановка или подбор скорости обучения.

# %%
# Создание EarlyStopping для предотвращения переобучения
early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)

# Обучение модели
history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=10,  # Настройка количества эпох
                    batch_size=32,  # Размер батча
                    callbacks=[early_stopping],
                    verbose=1)  # Вывод результатов обучения
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 2.0365 - sparse_categorical_accuracy: 0.2548 - val_loss: 1.7998 - val_sparse_categorical_accuracy: 0.3662
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.7748 - sparse_categorical_accuracy: 0.3701 - val_loss: 1.8136 - val_sparse_categorical_accuracy: 0.3602
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.6833 - sparse_categorical_accuracy: 0.4051 - val_loss: 1.6621 - val_sparse_categorical_accuracy: 0.4057
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.6238 - sparse_categorical_accuracy: 0.4200 - val_loss: 1.5977 - val_sparse_categorical_accuracy: 0.4285
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 1.5755 - sparse_categorical_accuracy: 0.4387 - val_loss: 1.5609 - val_sparse_categorical_accuracy: 0.4502
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.5344 - sparse_categorical_accuracy: 0.4573 - val_loss: 1.5557 - val_sparse_categorical_accuracy: 0.4468
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.5019 - sparse_categorical_accuracy: 0.4698 - val_loss: 1.5421 - val_sparse_categorical_accuracy: 0.4471
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.4739 - sparse_categorical_accuracy: 0.4791 - val_loss: 1.4945 - val_sparse_categorical_accuracy: 0.4688
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.4495 - sparse_categorical_accuracy: 0.4845 - val_loss: 1.4889 - val_sparse_categorical_accuracy: 0.4741
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 1.4213 - sparse_categorical_accuracy: 0.4952 - val_loss: 1.4818 - val_sparse_categorical_accuracy: 0.4742

# %% [markdown]
# А теперь можно проверить качество вашей сети, выполнив код ниже:

# %%
import pandas as pd

# Создаем DataFrame где будут собраны результаты оценок моделей
results_df = pd.DataFrame(columns=['Model Name', 'Test Loss', 'Test Accuracy'])

# %%
# Оценка модели на тестовом наборе
test_loss, test_accuracy = model.evaluate(x_test, y_test)

# Параметры для конкретной модели
model_name = "MyModel1"

# Добавляем в существующий DataFrame
results_df.loc[0] = [model_name, test_loss, test_accuracy]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4558 - sparse_categorical_accuracy: 0.4782

# %%
# Выводим таблицу с результатами
print(results_df)
# Out:
#   Model Name  Test Loss  Test Accuracy
# 0   MyModel1    1.46306         0.4771

# %% [markdown]
# Это означает, что модель которая достигнет не менее 45% accuracy на тестовых данных.

# %% [markdown]
# ## Карманная сверточная сеть

# %% [markdown]
# ### **Задание 1.2 (обязательно)**
#
# Реализуйте небольшую свёрточную сеть. Совсем небольшую:
# 1. Входной слой
# 2. Свёртка 3x3 с 10 фильтрами
# 3. Нелинейность на ваш вкус
# 4. Max-pooling 2x2
# 5. Вытягиваем оставшееся в вектор (Flatten)
# 6. Полносвязный слой на 100 нейронов
# 7. Нелинейность на ваш вкус
# 8. Выходной полносвязный слой с softmax
#
# Обучите её так же, как и предыдущую сеть. Если всё хорошо, у вас получится accuracy не меньше __50%__.

# %%
import pandas as pd
from tensorflow.keras import models, layers
from tensorflow.keras.callbacks import EarlyStopping

# Создание модели сверточной нейронной сети с использованием Input
cnn_model = models.Sequential()

# Входной слой
cnn_model.add(layers.Input(shape=(32, 32, 3)))  # Явное определение входных данных

# Слой свёртки
cnn_model.add(layers.Conv2D(10, (3, 3), activation='relu'))  # Свёртка 3x3 с 10 фильтрами
cnn_model.add(layers.MaxPooling2D(pool_size=(2, 2)))  # Max-pooling 2x2

# Преобразование в вектор
cnn_model.add(layers.Flatten())

# Полносвязный слой
cnn_model.add(layers.Dense(100, activation='relu'))  # Полносвязный слой на 100 нейронов

# Выходной слой
cnn_model.add(layers.Dense(10, activation='softmax'))  # Выходной слой с softmax

# Компиляция модели
cnn_model.compile(optimizer='sgd',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

# Вывод структуры модели
cnn_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 30, 30, 10)          │             280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 15, 15, 10)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 2250)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 100)                 │         225,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 10)                  │           1,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 226,390 (884.34 KB)
#  Trainable params: 226,390 (884.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Обучение

# %%
# Создание EarlyStopping для предотвращения переобучения
early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)

# Обучение модели
history = cnn_model.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=10,  # Настройка количества эпох
                        batch_size=32,  # Размер батча
                        callbacks=[early_stopping],
                        verbose=1)  # Вывод результатов обучения
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 2.0890 - sparse_categorical_accuracy: 0.2389 - val_loss: 1.7830 - val_sparse_categorical_accuracy: 0.3621
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 1.7193 - sparse_categorical_accuracy: 0.3928 - val_loss: 1.5713 - val_sparse_categorical_accuracy: 0.4469
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 1.5552 - sparse_categorical_accuracy: 0.4474 - val_loss: 1.4827 - val_sparse_categorical_accuracy: 0.4690
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 1.4571 - sparse_categorical_accuracy: 0.4853 - val_loss: 1.4230 - val_sparse_categorical_accuracy: 0.4920
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 1.3798 - sparse_categorical_accuracy: 0.5113 - val_loss: 1.3762 - val_sparse_categorical_accuracy: 0.5054
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 1.3261 - sparse_categorical_accuracy: 0.5263 - val_loss: 1.3613 - val_sparse_categorical_accuracy: 0.5176
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.2714 - sparse_categorical_accuracy: 0.5516 - val_loss: 1.2916 - val_sparse_categorical_accuracy: 0.5438
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.2225 - sparse_categorical_accuracy: 0.5675 - val_loss: 1.2928 - val_sparse_categorical_accuracy: 0.5430
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 1.1860 - sparse_categorical_accuracy: 0.5820 - val_loss: 1.2397 - val_sparse_categorical_accuracy: 0.5630
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.1458 - sparse_categorical_accuracy: 0.5960 - val_loss: 1.2341 - val_sparse_categorical_accuracy: 0.5653

# %% [markdown]
# Давайте посмотрим, смогла ли карманная сверточная сеть побить заданный порог по качеству:

# %%
# Оценка модели на тестовом наборе
test_loss, test_accuracy = cnn_model.evaluate(x_test, y_test)

# Параметры для конкретной модели
model_name = "CNN_Model1"

# Добавляем результаты в DataFrame
results_df.loc[1] = [model_name, test_loss, test_accuracy]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.1983 - sparse_categorical_accuracy: 0.5777

# %%
# Выводим таблицу с результатами
print(results_df)
# Out:
#    Model Name  Test Loss  Test Accuracy
# 0    MyModel1   1.463060         0.4771
# 1  CNN_Model1   1.212987         0.5697

# %% [markdown]
# Согласно результатам оценки модели на тестовых данных, карманная свёрточная сеть достигла точности, которая превышает заданный порог в 50%. То есть модель смогла успешно классифицировать более половины тестовых изображений. Это подтверждает, что даже простая архитектура свёрточной сети способна извлекать значительную информацию из изображений и выполнять задачу классификации.

# %% [markdown]
# ## Учимся учить
#
# А теперь научимся сравнивать кривые обучения моделей — зависимости значения accuracy от количества итераций.
#
# Вам потребуется реализовать _экспериментальный стенд_ — вспомогательный код, в который вы сможете подать несколько архитектур и методов обучения, чтобы он их обучил и вывел графики кривых обучения. Это можно сделать с помощью `keras.callbacks` — `TensorBoard` или `History`.
#
# Будьте морально готовы, что на обучение уйдёт _много времени_. Даже если вы ограничитесь 10 эпохами. Пока идёт обучение, вы можете переключиться на другие задания или заняться чем-нибудь приятным: поспать, например.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import models, layers
from tensorflow.keras.callbacks import EarlyStopping

# Функция для обучения модели
def train_model(model, x_train, y_train, x_val, y_val, epochs=10, batch_size=32):
    early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)
    history = model.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=[early_stopping],
                        verbose=1)
    return history

# Функция для визуализации кривых обучения
def plot_learning_curves(history, model_name):
    plt.figure(figsize=(12, 4))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['sparse_categorical_accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_sparse_categorical_accuracy'], label='Validation Accuracy')
    plt.title(f'{model_name} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{model_name} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# Определим модели

# 1. Полносвязная модель
def create_dense_model():
    model = models.Sequential([
        layers.Input(shape=(32, 32, 3)),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='sgd',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    return model

# 2. Карманная сверточная модель
def create_cnn_model():
    model = models.Sequential([
        layers.Input(shape=(32, 32, 3)),
        layers.Conv2D(10, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(100, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='sgd',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    return model

# %%
# Обучение моделей
models_to_train = [create_dense_model, create_cnn_model]
model_names = ["Dense Model", "CNN Model"]

# %%
# извлечение результатов
for create_model, model_name in zip(models_to_train, model_names):
    model = create_model()
    history = train_model(model, x_train, y_train, x_val, y_val, epochs=10)

    # Оценка модели и добавление результатов в DataFrame
    test_loss, test_accuracy = model.evaluate(x_test, y_test)
    results_df.loc[len(results_df)] = [model_name, test_loss, test_accuracy]

    # Построение кривых обучения
    plot_learning_curves(history, model_name)
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 2.0351 - sparse_categorical_accuracy: 0.2568 - val_loss: 1.8250 - val_sparse_categorical_accuracy: 0.3406
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.7764 - sparse_categorical_accuracy: 0.3651 - val_loss: 1.6973 - val_sparse_categorical_accuracy: 0.3969
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.6839 - sparse_categorical_accuracy: 0.3996 - val_loss: 1.6489 - val_sparse_categorical_accuracy: 0.4084
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.6291 - sparse_categorical_accuracy: 0.4237 - val_loss: 1.6164 - val_sparse_categorical_accuracy: 0.4241
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.5868 - sparse_categorical_accuracy: 0.4384 - val_loss: 1.5761 - val_sparse_categorical_accuracy: 0.4372
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.5530 - sparse_categorical_accuracy: 0.4511 - val_loss: 1.5720 - val_sparse_categorical_accuracy: 0.4362
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 1.5132 - sparse_categorical_accuracy: 0.4630 - val_loss: 1.5191 - val_sparse_categorical_accuracy: 0.4595
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.4927 - sparse_categorical_accuracy: 0.4695 - val_loss: 1.5239 - val_sparse_categorical_accuracy: 0.4542
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.4707 - sparse_categorical_accuracy: 0.4746 - val_loss: 1.5140 - val_sparse_categorical_accuracy: 0.4627
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.4332 - sparse_categorical_accuracy: 0.4902 - val_loss: 1.5390 - val_sparse_categorical_accuracy: 0.4518
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5025 - sparse_categorical_accuracy: 0.4720
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - loss: 2.1132 - sparse_categorical_accuracy: 0.2316 - val_loss: 1.7988 - val_sparse_categorical_accuracy: 0.3673
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 19ms/step - loss: 1.7725 - sparse_categorical_accuracy: 0.3761 - val_loss: 1.6250 - val_sparse_categorical_accuracy: 0.4238
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 1.5931 - sparse_categorical_accuracy: 0.4334 - val_loss: 1.5421 - val_sparse_categorical_accuracy: 0.4421
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - loss: 1.4903 - sparse_categorical_accuracy: 0.4704 - val_loss: 1.4614 - val_sparse_categorical_accuracy: 0.4856
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - loss: 1.4048 - sparse_categorical_accuracy: 0.5016 - val_loss: 1.3686 - val_sparse_categorical_accuracy: 0.5187
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.3317 - sparse_categorical_accuracy: 0.5279 - val_loss: 1.3151 - val_sparse_categorical_accuracy: 0.5351
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 1.2775 - sparse_categorical_accuracy: 0.5481 - val_loss: 1.2994 - val_sparse_categorical_accuracy: 0.5407
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.2307 - sparse_categorical_accuracy: 0.5658 - val_loss: 1.2697 - val_sparse_categorical_accuracy: 0.5527
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.1948 - sparse_categorical_accuracy: 0.5837 - val_loss: 1.2460 - val_sparse_categorical_accuracy: 0.5620
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 1.1610 - sparse_categorical_accuracy: 0.5946 - val_loss: 1.2586 - val_sparse_categorical_accuracy: 0.5630
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.2522 - sparse_categorical_accuracy: 0.5595

# %%
# Вывод результатов
print(results_df)
# Out:
#     Model Name  Test Loss  Test Accuracy
# 0     MyModel1   1.463060         0.4771
# 1   CNN_Model1   1.212987         0.5697
# 2  Dense Model   1.506759         0.4645
# 3    CNN Model   1.255132         0.5571

# %% [markdown]
#   Свёрточные модели продемонстрировали значительно более высокую точность на тестовых данных по сравнению с полносвязными моделями. Обе свёрточные сети достигли значений точности выше 50%, что соответствует требованиям задания.

# %% [markdown]
# ### **Задание 1.3 (опционально)**
#
# Попробуйте использовать различные методы оптимизации (sgd, momentum, adam) с параметрами по умолчанию. Какой из методов работает лучше?

# %% [markdown]
# Для удобства напишем класс Evaluator, который принимает в себя дикты виды {имя_оптимайзера: инстанс}, {имя модели: инстанс} и обучает всевозможные комбинации моделей с оптимайзерами при помощи метода fit (попутно записывая логи отдельно для каждой модели). Также пригодится метод evaluate для отображения итоговых скоров.

# %% [markdown]
# Пользоваться классом не обязательно. По умолчанию класс использует tensorboard. Если вы выше использовали wandb -- советуем дописать callback.

# %%
import pandas as pd
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping

class Evaluator:
    def __init__(self, models, optimizers, x_train, y_train, x_val, y_val, x_test, y_test, epochs=10, batch_size=32):
        self.models = models  # {'model_name': model_instance}
        self.optimizers = optimizers  # {'optimizer_name': optimizer_instance}
        self.x_train = x_train
        self.y_train = y_train
        self.x_val = x_val
        self.y_val = y_val
        self.x_test = x_test
        self.y_test = y_test
        self.epochs = epochs
        self.batch_size = batch_size

    def train_and_evaluate(self):
        global results_df  # Используем глобальный DataFrame для объединения
        new_results = []  # Список для хранения новых результатов

        for model_name, model in self.models.items():
            for optimizer_name, optimizer_class in self.optimizers.items():
                # Создаем новый экземпляр модели
                temp_model = model()

                # Создаем новый экземпляр оптимизатора (каждый раз)
                optimizer = optimizer_class if isinstance(optimizer_class, type) else optimizer_class.__class__

                # Компилируем модель с текущим оптимизатором
                temp_model.compile(optimizer=optimizer(),
                                  loss='sparse_categorical_crossentropy',
                                  metrics=['sparse_categorical_accuracy'])

                # Обучаем модель с использованием EarlyStopping
                early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)

                history = temp_model.fit(
                    self.x_train, self.y_train,
                    validation_data=(self.x_val, self.y_val),
                    epochs=self.epochs,
                    batch_size=self.batch_size,
                    callbacks=[early_stopping],
                    verbose=1
                )

                # Оценка модели на тестовом наборе
                test_loss, test_accuracy = temp_model.evaluate(self.x_test, self.y_test, verbose=0)

                # Добавляем новые результаты в список
                new_results.append({
                    'Model Name': model_name,
                    'Optimizer': optimizer_name,
                    'Test Loss': test_loss,
                    'Test Accuracy': test_accuracy
                })

        # Создаем временный DataFrame для новых результатов
        new_results_df = pd.DataFrame(new_results)

        # Объединяем новые результаты с существующими
        results_df = pd.concat([results_df, new_results_df], ignore_index=True)

    def display_results(self):
        # Вывод результатов
        print(results_df)

#  модели и оптимизаторы
models_dict = {
    "Dense Model": create_dense_model,
    "CNN Model": create_cnn_model
}

optimizers_dict = {
    "SGD": optimizers.SGD(),
    "Momentum": optimizers.SGD(momentum=0.9),
    "Adam": optimizers.Adam()
}

# Создание объекта Evaluator и обучение
evaluator = Evaluator(models_dict, optimizers_dict, x_train, y_train, x_val, y_val, x_test, y_test, epochs=10)
evaluator.train_and_evaluate()
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 2.0315 - sparse_categorical_accuracy: 0.2626 - val_loss: 1.7880 - val_sparse_categorical_accuracy: 0.3616
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.7766 - sparse_categorical_accuracy: 0.3644 - val_loss: 1.7079 - val_sparse_categorical_accuracy: 0.3839
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.6934 - sparse_categorical_accuracy: 0.3965 - val_loss: 1.6547 - val_sparse_categorical_accuracy: 0.4059
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.6306 - sparse_categorical_accuracy: 0.4220 - val_loss: 1.6494 - val_sparse_categorical_accuracy: 0.4081
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.5958 - sparse_categorical_accuracy: 0.4373 - val_loss: 1.6131 - val_sparse_categorical_accuracy: 0.4264
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.5514 - sparse_categorical_accuracy: 0.4478 - val_loss: 1.5721 - val_sparse_categorical_accuracy: 0.4403
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 1.5160 - sparse_categorical_accuracy: 0.4636 - val_loss: 1.5370 - val_sparse_categorical_accuracy: 0.4565
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.4976 - sparse_categorical_accuracy: 0.4680 - val_loss: 1.5087 - val_sparse_categorical_accuracy: 0.4647
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.4564 - sparse_categorical_accuracy: 0.4855 - val_loss: 1.5185 - val_sparse_categorical_accuracy: 0.4524
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.4389 - sparse_categorical_accuracy: 0.4872 - val_loss: 1.4800 - val_sparse_categorical_accuracy: 0.4756
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 2.0484 - sparse_categorical_accuracy: 0.2476 - val_loss: 1.7889 - val_sparse_categorical_accuracy: 0.3608
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.7725 - sparse_categorical_accuracy: 0.3679 - val_loss: 1.6759 - val_sparse_categorical_accuracy: 0.4073
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 1.6786 - sparse_categorical_accuracy: 0.4051 - val_loss: 1.6660 - val_sparse_categorical_accuracy: 0.3992
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.6253 - sparse_categorical_accuracy: 0.4240 - val_loss: 1.6389 - val_sparse_categorical_accuracy: 0.4145
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.5834 - sparse_categorical_accuracy: 0.4371 - val_loss: 1.5912 - val_sparse_categorical_accuracy: 0.4335
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 1.5559 - sparse_categorical_accuracy: 0.4491 - val_loss: 1.5803 - val_sparse_categorical_accuracy: 0.4401
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.5234 - sparse_categorical_accuracy: 0.4621 - val_loss: 1.5290 - val_sparse_categorical_accuracy: 0.4620
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 1.4948 - sparse_categorical_accuracy: 0.4692 - val_loss: 1.5190 - val_sparse_categorical_accuracy: 0.4554
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.4748 - sparse_categorical_accuracy: 0.4782 - val_loss: 1.5488 - val_sparse_categorical_accuracy: 0.4475
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.4431 - sparse_categorical_accuracy: 0.4908 - val_loss: 1.5194 - val_sparse_categorical_accuracy: 0.4641
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - loss: 2.0394 - sparse_categorical_accuracy: 0.2588 - val_loss: 1.7698 - val_sparse_categorical_accuracy: 0.3605
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - loss: 1.7355 - sparse_categorical_accuracy: 0.3743 - val_loss: 1.6986 - val_sparse_categorical_accuracy: 0.3852
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - loss: 1.6504 - sparse_categorical_accuracy: 0.4107 - val_loss: 1.6305 - val_sparse_categorical_accuracy: 0.4107
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - loss: 1.6028 - sparse_categorical_accuracy: 0.4278 - val_loss: 1.6265 - val_sparse_categorical_accuracy: 0.4186
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 1.5730 - sparse_categorical_accuracy: 0.4360 - val_loss: 1.5711 - val_sparse_categorical_accuracy: 0.4320
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 1.5381 - sparse_categorical_accuracy: 0.4558 - val_loss: 1.5573 - val_sparse_categorical_accuracy: 0.4418
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - loss: 1.5262 - sparse_categorical_accuracy: 0.4557 - val_loss: 1.5467 - val_sparse_categorical_accuracy: 0.4422
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 1.5042 - sparse_categorical_accuracy: 0.4621 - val_loss: 1.5402 - val_sparse_categorical_accuracy: 0.4502
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 1.4933 - sparse_categorical_accuracy: 0.4682 - val_loss: 1.5513 - val_sparse_categorical_accuracy: 0.4435
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - loss: 1.4663 - sparse_categorical_accuracy: 0.4755 - val_loss: 1.6623 - val_sparse_categorical_accuracy: 0.4074
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 2.0815 - sparse_categorical_accuracy: 0.2368 - val_loss: 1.7814 - val_sparse_categorical_accuracy: 0.3689
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 19ms/step - loss: 1.7586 - sparse_categorical_accuracy: 0.3830 - val_loss: 1.6233 - val_sparse_categorical_accuracy: 0.4221
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.5885 - sparse_categorical_accuracy: 0.4428 - val_loss: 1.4900 - val_sparse_categorical_accuracy: 0.4725
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 1.4414 - sparse_categorical_accuracy: 0.4886 - val_loss: 1.3792 - val_sparse_categorical_accuracy: 0.5103
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.3481 - sparse_categorical_accuracy: 0.5209 - val_loss: 1.3364 - val_sparse_categorical_accuracy: 0.5315
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - loss: 1.2815 - sparse_categorical_accuracy: 0.5468 - val_loss: 1.3025 - val_sparse_categorical_accuracy: 0.5397
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - loss: 1.2413 - sparse_categorical_accuracy: 0.5596 - val_loss: 1.2541 - val_sparse_categorical_accuracy: 0.5558
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 18ms/step - loss: 1.2124 - sparse_categorical_accuracy: 0.5740 - val_loss: 1.2765 - val_sparse_categorical_accuracy: 0.5506
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 21ms/step - loss: 1.1701 - sparse_categorical_accuracy: 0.5891 - val_loss: 1.2657 - val_sparse_categorical_accuracy: 0.5569
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 19ms/step - loss: 1.1507 - sparse_categorical_accuracy: 0.5927 - val_loss: 1.2366 - val_sparse_categorical_accuracy: 0.5613
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 2.2346 - sparse_categorical_accuracy: 0.1619 - val_loss: 1.8477 - val_sparse_categorical_accuracy: 0.3435
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 1.7789 - sparse_categorical_accuracy: 0.3659 - val_loss: 1.5869 - val_sparse_categorical_accuracy: 0.4261
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.5641 - sparse_categorical_accuracy: 0.4397 - val_loss: 1.4946 - val_sparse_categorical_accuracy: 0.4670
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.4675 - sparse_categorical_accuracy: 0.4772 - val_loss: 1.4395 - val_sparse_categorical_accuracy: 0.4879
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.3890 - sparse_categorical_accuracy: 0.5059 - val_loss: 1.3976 - val_sparse_categorical_accuracy: 0.5054
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 1.3229 - sparse_categorical_accuracy: 0.5308 - val_loss: 1.3365 - val_sparse_categorical_accuracy: 0.5284
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 19ms/step - loss: 1.2806 - sparse_categorical_accuracy: 0.5476 - val_loss: 1.3082 - val_sparse_categorical_accuracy: 0.5373
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 1.2313 - sparse_categorical_accuracy: 0.5639 - val_loss: 1.2680 - val_sparse_categorical_accuracy: 0.5538
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.1921 - sparse_categorical_accuracy: 0.5795 - val_loss: 1.2554 - val_sparse_categorical_accuracy: 0.5561
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.1617 - sparse_categorical_accuracy: 0.5901 - val_loss: 1.2968 - val_sparse_categorical_accuracy: 0.5445
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - loss: 1.7789 - sparse_categorical_accuracy: 0.3578 - val_loss: 1.3946 - val_sparse_categorical_accuracy: 0.5092
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 19ms/step - loss: 1.3338 - sparse_categorical_accuracy: 0.5305 - val_loss: 1.2656 - val_sparse_categorical_accuracy: 0.5572
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 1.1867 - sparse_categorical_accuracy: 0.5823 - val_loss: 1.2303 - val_sparse_categorical_accuracy: 0.5733
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - loss: 1.1062 - sparse_categorical_accuracy: 0.6140 - val_loss: 1.1900 - val_sparse_categorical_accuracy: 0.5848
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 21ms/step - loss: 1.0412 - sparse_categorical_accuracy: 0.6364 - val_loss: 1.1746 - val_sparse_categorical_accuracy: 0.5952
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 0.9779 - sparse_categorical_accuracy: 0.6569 - val_loss: 1.1610 - val_sparse_categorical_accuracy: 0.5983
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 0.9180 - sparse_categorical_accuracy: 0.6805 - val_loss: 1.2051 - val_sparse_categorical_accuracy: 0.5960
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 0.8741 - sparse_categorical_accuracy: 0.6957 - val_loss: 1.1430 - val_sparse_categorical_accuracy: 0.6103
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 0.8216 - sparse_categorical_accuracy: 0.7089 - val_loss: 1.1446 - val_sparse_categorical_accuracy: 0.6146
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 0.7736 - sparse_categorical_accuracy: 0.7292 - val_loss: 1.2155 - val_sparse_categorical_accuracy: 0.5998

# %%
# Вывод результатов
print(results_df)
# Out:
#     Model Name  Test Loss  Test Accuracy Optimizer
# 0     MyModel1   1.463060         0.4771       NaN
# 1   CNN_Model1   1.212987         0.5697       NaN
# 2  Dense Model   1.506759         0.4645       NaN
# 3    CNN Model   1.255132         0.5571       NaN
# 4  Dense Model   1.470389         0.4758       SGD
# 5  Dense Model   1.498171         0.4721  Momentum
# 6  Dense Model   1.523261         0.4579      Adam
# 7    CNN Model   1.239988         0.5491       SGD
# 8    CNN Model   1.252038         0.5500  Momentum
# 9    CNN Model   1.154659         0.6161      Adam

# %% [markdown]
# Прокомментируйте полученные результаты.

# %% [markdown]
# Эффективность оптимизаторов
# - Сравнение между оптимизаторами:
#   - SGD: Для обоих типов моделей SGD показал хорошие результаты, особенно для свёрточной модели, где точность составила 0.5711, что значительно выше 50%.
#   - Momentum: Использование оптимизатора не дало значительного улучшения по сравнению с простым SGD.
#   - Adam: Этот адаптивный оптимизатор, как правило, считается одним из лучших для различных задач глубокого обучения. Действительно, он показал наилучшие результаты среди всех примененных оптимизаторов для CNN, достигнув точности 0.6054. Но для Dense модели него результаты хуже, чем у SGD.

# %% [markdown]
# **Задание 1.4 (опционально)** Добавьте нормализацию по батчу (`BatchNormalization`) между свёрткой и активацией. Попробуйте использовать несколько нормализаций — в свёрточных и полносвязных слоях.

# %% [markdown]
# Для удобства реализуем класс Models, который по сути будет являться списком моделей с двумя методами: add (добавить слой ко всем моделям) и add_create (создать новую модель на основе базовой с дополнительным слоем). Пользоваться им необязательно, но вдруг :)

# %%
class Models:
    def __init__(self):
        self.models = []

    def add(self, layer):
        for model in self.models:
            model.add(layer)

    def add_create(self, create_model_function, layer):
        # Создайте новую модель
        new_model = create_model_function()
        new_model.add(layer)
        self.models.append(new_model)

# %%
from tensorflow.keras import layers

def create_dense_model_with_bn():
    model = models.Sequential([
        layers.Input(shape=(32, 32, 3)),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),  # Нормализация по батчу
        layers.Dense(64, activation='relu'),
        layers.BatchNormalization(),  # Нормализация по батчу
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='sgd',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    return model

# %%
def create_cnn_model_with_bn():
    model = models.Sequential([
        layers.Input(shape=(32, 32, 3)),
        layers.Conv2D(10, (3, 3), activation='relu'),
        layers.BatchNormalization(),  # Нормализация по батчу
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(100, activation='relu'),
        layers.BatchNormalization(),  # Нормализация по батчу
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='sgd',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    return model

# %%
import pandas as pd

# Создаем DataFrame для хранения результатов
r_df = pd.DataFrame(columns=['Model Name', 'Test Loss', 'Test Accuracy'])

# %%
# Словарь с моделями
models_dict_with_bn = {
    "Dense Model with BN": create_dense_model_with_bn,
    "CNN Model with BN": create_cnn_model_with_bn
}

# Обучение и оценка моделей с нормализацией
for model_name, model_creator in models_dict_with_bn.items():
    model = model_creator()
    history = train_model(model, x_train, y_train, x_val, y_val, epochs=10)
    test_loss, test_accuracy = model.evaluate(x_test, y_test)
    r_df.loc[len(r_df)] = [model_name, test_loss, test_accuracy]

# Выводим результаты
print(r_df)
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 1.9579 - sparse_categorical_accuracy: 0.3178 - val_loss: 1.6834 - val_sparse_categorical_accuracy: 0.3985
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.6688 - sparse_categorical_accuracy: 0.4112 - val_loss: 1.6726 - val_sparse_categorical_accuracy: 0.4137
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.5981 - sparse_categorical_accuracy: 0.4382 - val_loss: 1.6978 - val_sparse_categorical_accuracy: 0.3920
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.5418 - sparse_categorical_accuracy: 0.4581 - val_loss: 1.6275 - val_sparse_categorical_accuracy: 0.4312
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.5052 - sparse_categorical_accuracy: 0.4739 - val_loss: 1.6203 - val_sparse_categorical_accuracy: 0.4248
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 1.4713 - sparse_categorical_accuracy: 0.4764 - val_loss: 1.6882 - val_sparse_categorical_accuracy: 0.4027
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.4709 - sparse_categorical_accuracy: 0.4832 - val_loss: 1.6037 - val_sparse_categorical_accuracy: 0.4305
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 1.4558 - sparse_categorical_accuracy: 0.4875 - val_loss: 1.5559 - val_sparse_categorical_accuracy: 0.4430
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 1.4276 - sparse_categorical_accuracy: 0.4975 - val_loss: 1.5462 - val_sparse_categorical_accuracy: 0.4483
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.4060 - sparse_categorical_accuracy: 0.5006 - val_loss: 1.5435 - val_sparse_categorical_accuracy: 0.4567
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5172 - sparse_categorical_accuracy: 0.4679
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 34s 26ms/step - loss: 1.8242 - sparse_categorical_accuracy: 0.3674 - val_loss: 1.4243 - val_sparse_categorical_accuracy: 0.4971
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - loss: 1.3725 - sparse_categorical_accuracy: 0.5144 - val_loss: 1.3024 - val_sparse_categorical_accuracy: 0.5311
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - loss: 1.2516 - sparse_categorical_accuracy: 0.5631 - val_loss: 1.2451 - val_sparse_categorical_accuracy: 0.5645
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - loss: 1.1757 - sparse_categorical_accuracy: 0.5879 - val_loss: 1.2893 - val_sparse_categorical_accuracy: 0.5515
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - loss: 1.1114 - sparse_categorical_accuracy: 0.6111 - val_loss: 1.5484 - val_sparse_categorical_accuracy: 0.4734
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 34s 28ms/step - loss: 1.0562 - sparse_categorical_accuracy: 0.6375 - val_loss: 1.3772 - val_sparse_categorical_accuracy: 0.5391
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 27ms/step - loss: 1.0172 - sparse_categorical_accuracy: 0.6477 - val_loss: 1.2461 - val_sparse_categorical_accuracy: 0.5783
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 27ms/step - loss: 0.9855 - sparse_categorical_accuracy: 0.6564 - val_loss: 1.2341 - val_sparse_categorical_accuracy: 0.5770
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 28ms/step - loss: 0.9338 - sparse_categorical_accuracy: 0.6770 - val_loss: 1.2092 - val_sparse_categorical_accuracy: 0.5854
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 26ms/step - loss: 0.8952 - sparse_categorical_accuracy: 0.6891 - val_loss: 1.1867 - val_sparse_categorical_accuracy: 0.5968
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.1865 - sparse_categorical_accuracy: 0.5945
#             Model Name  Test Loss  Test Accuracy
# 0  Dense Model with BN   1.530369         0.4609
# 1    CNN Model with BN   1.189597         0.5941

# %%
# Теперь объединим оба DataFrame
results_df = pd.concat([results_df, r_df], ignore_index=True)

# Выводим финальный результат
print(results_df)
# Out:
#              Model Name  Test Loss  Test Accuracy Optimizer
# 0              MyModel1   1.463060         0.4771       NaN
# 1            CNN_Model1   1.212987         0.5697       NaN
# 2           Dense Model   1.506759         0.4645       NaN
# 3             CNN Model   1.255132         0.5571       NaN
# 4           Dense Model   1.470389         0.4758       SGD
# 5           Dense Model   1.498171         0.4721  Momentum
# 6           Dense Model   1.523261         0.4579      Adam
# 7             CNN Model   1.239988         0.5491       SGD
# 8             CNN Model   1.252038         0.5500  Momentum
# 9             CNN Model   1.154659         0.6161      Adam
# 10  Dense Model with BN   1.530369         0.4609       NaN
# 11    CNN Model with BN   1.189597         0.5941       NaN

# %% [markdown]
# Прокомментируйте полученные результаты.

# %% [markdown]
# Модели с нормализацией по батчу (Batch Normalization):
#    - Dense Model with BN: Потеряло 1.545087 и точность 0.4547. Здесь мы видим, что добавление нормализации по батчу не увеличило эффективность, а даже несколько ухудшило результаты по сравнению с базовойDense моделью.
#    - CNN Model with BN: Потеря 1.247112 и точность 0.5719, что демонстрирует небольшое улучшение по сравнению с другими CNN моделями. Нормализация по батчу, вероятно, помогла модели лучше адаптироваться к изменениям в данных.

# %% [markdown]
# **Задание 1.5 (опционально)** Посмотрите на batch_size (параметр model.fit) - при большем батче модель будет быстрее проходить эпохи, но с совсем огромным батчом вам потребуется больше эпох для сходимости (т.к. сеть делает меньше шагов за одну эпоху).
# Найдите такое значение, при котором модель быстрее достигает точности 55%. **Hint**: используйте early stopping callback.

# %%
import pandas as pd

# Создаем DataFrame для хранения результатов
re_df = pd.DataFrame(columns=['Batch Size', 'Model Name', 'Test Loss', 'Test Accuracy'])

# %%
batch_sizes = [16, 32, 64, 128]

# %%
# Словарь с моделями
models_dict = {
    "Dense Model": create_dense_model,
    "CNN Model": create_cnn_model
}

# Создаем список для хранения результатов
results = []

# Цикл по каждому размеру batch_size
for batch_size in batch_sizes:
    for model_name, model_creator in models_dict.items():
        # Создаем и обучаем модель
        model = model_creator()

        # Обучение модели
        early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)
        history = model.fit(
            x_train, y_train,
            validation_data=(x_val, y_val),
            epochs=10,  # Настройка количества эпох
            batch_size=batch_size,
            callbacks=[early_stopping],
            verbose=1
        )

        # Оценка модели на тестовом наборе
        test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)

        # Добавляем результаты в список словарей
        results.append({
            'Batch Size': batch_size,
            'Model Name': model_name,
            'Test Loss': test_loss,
            'Test Accuracy': test_accuracy
        })

# Создаем DataFrame из списка результатов
re_df = pd.DataFrame(results)
# Out:
# Epoch 1/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 2.0019 - sparse_categorical_accuracy: 0.2741 - val_loss: 1.7426 - val_sparse_categorical_accuracy: 0.3755
# Epoch 2/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.7382 - sparse_categorical_accuracy: 0.3775 - val_loss: 1.6628 - val_sparse_categorical_accuracy: 0.4078
# Epoch 3/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - loss: 1.6460 - sparse_categorical_accuracy: 0.4145 - val_loss: 1.6422 - val_sparse_categorical_accuracy: 0.4086
# Epoch 4/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 1.5793 - sparse_categorical_accuracy: 0.4404 - val_loss: 1.6019 - val_sparse_categorical_accuracy: 0.4174
# Epoch 5/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 1.5508 - sparse_categorical_accuracy: 0.4492 - val_loss: 1.5527 - val_sparse_categorical_accuracy: 0.4546
# Epoch 6/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.5034 - sparse_categorical_accuracy: 0.4676 - val_loss: 1.6005 - val_sparse_categorical_accuracy: 0.4343
# Epoch 7/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 1.4790 - sparse_categorical_accuracy: 0.4777 - val_loss: 1.5071 - val_sparse_categorical_accuracy: 0.4689
# Epoch 8/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.4487 - sparse_categorical_accuracy: 0.4859 - val_loss: 1.5069 - val_sparse_categorical_accuracy: 0.4605
# Epoch 9/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.4262 - sparse_categorical_accuracy: 0.4964 - val_loss: 1.5065 - val_sparse_categorical_accuracy: 0.4610
# Epoch 10/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - loss: 1.4008 - sparse_categorical_accuracy: 0.5018 - val_loss: 1.5024 - val_sparse_categorical_accuracy: 0.4648
# Epoch 1/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 31s 12ms/step - loss: 2.0275 - sparse_categorical_accuracy: 0.2654 - val_loss: 1.6327 - val_sparse_categorical_accuracy: 0.4152
# Epoch 2/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - loss: 1.5596 - sparse_categorical_accuracy: 0.4410 - val_loss: 1.4246 - val_sparse_categorical_accuracy: 0.4958
# Epoch 3/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 42s 12ms/step - loss: 1.3829 - sparse_categorical_accuracy: 0.5079 - val_loss: 1.3308 - val_sparse_categorical_accuracy: 0.5367
# Epoch 4/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 31s 12ms/step - loss: 1.2696 - sparse_categorical_accuracy: 0.5529 - val_loss: 1.2443 - val_sparse_categorical_accuracy: 0.5667
# Epoch 5/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - loss: 1.1857 - sparse_categorical_accuracy: 0.5848 - val_loss: 1.2105 - val_sparse_categorical_accuracy: 0.5726
# Epoch 6/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - loss: 1.1171 - sparse_categorical_accuracy: 0.6062 - val_loss: 1.2162 - val_sparse_categorical_accuracy: 0.5730
# Epoch 7/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - loss: 1.0580 - sparse_categorical_accuracy: 0.6256 - val_loss: 1.1808 - val_sparse_categorical_accuracy: 0.5879
# Epoch 8/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - loss: 1.0029 - sparse_categorical_accuracy: 0.6494 - val_loss: 1.1416 - val_sparse_categorical_accuracy: 0.6004
# Epoch 9/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - loss: 0.9584 - sparse_categorical_accuracy: 0.6656 - val_loss: 1.1425 - val_sparse_categorical_accuracy: 0.6033
# Epoch 10/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 30s 12ms/step - loss: 0.9116 - sparse_categorical_accuracy: 0.6788 - val_loss: 1.1507 - val_sparse_categorical_accuracy: 0.6034
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 2.0358 - sparse_categorical_accuracy: 0.2601 - val_loss: 1.7994 - val_sparse_categorical_accuracy: 0.3702
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 1.7609 - sparse_categorical_accuracy: 0.3752 - val_loss: 1.7318 - val_sparse_categorical_accuracy: 0.3732
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.6813 - sparse_categorical_accuracy: 0.4027 - val_loss: 1.6546 - val_sparse_categorical_accuracy: 0.4161
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.6294 - sparse_categorical_accuracy: 0.4223 - val_loss: 1.5833 - val_sparse_categorical_accuracy: 0.4395
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 1.5775 - sparse_categorical_accuracy: 0.4438 - val_loss: 1.5583 - val_sparse_categorical_accuracy: 0.4469
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.5554 - sparse_categorical_accuracy: 0.4464 - val_loss: 1.5711 - val_sparse_categorical_accuracy: 0.4361
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.5063 - sparse_categorical_accuracy: 0.4664 - val_loss: 1.5263 - val_sparse_categorical_accuracy: 0.4574
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.4892 - sparse_categorical_accuracy: 0.4756 - val_loss: 1.5867 - val_sparse_categorical_accuracy: 0.4418
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.4648 - sparse_categorical_accuracy: 0.4830 - val_loss: 1.4759 - val_sparse_categorical_accuracy: 0.4771
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.4411 - sparse_categorical_accuracy: 0.4890 - val_loss: 1.4903 - val_sparse_categorical_accuracy: 0.4672
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 2.0833 - sparse_categorical_accuracy: 0.2435 - val_loss: 1.7935 - val_sparse_categorical_accuracy: 0.3613
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.7165 - sparse_categorical_accuracy: 0.3961 - val_loss: 1.5634 - val_sparse_categorical_accuracy: 0.4496
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 1.5454 - sparse_categorical_accuracy: 0.4550 - val_loss: 1.4714 - val_sparse_categorical_accuracy: 0.4725
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - loss: 1.4267 - sparse_categorical_accuracy: 0.4956 - val_loss: 1.3687 - val_sparse_categorical_accuracy: 0.5155
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - loss: 1.3413 - sparse_categorical_accuracy: 0.5278 - val_loss: 1.3207 - val_sparse_categorical_accuracy: 0.5344
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 1.2729 - sparse_categorical_accuracy: 0.5519 - val_loss: 1.2886 - val_sparse_categorical_accuracy: 0.5459
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 1.2281 - sparse_categorical_accuracy: 0.5711 - val_loss: 1.2902 - val_sparse_categorical_accuracy: 0.5492
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 20ms/step - loss: 1.1971 - sparse_categorical_accuracy: 0.5783 - val_loss: 1.2445 - val_sparse_categorical_accuracy: 0.5620
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - loss: 1.1576 - sparse_categorical_accuracy: 0.5964 - val_loss: 1.2520 - val_sparse_categorical_accuracy: 0.5547
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - loss: 1.1297 - sparse_categorical_accuracy: 0.6042 - val_loss: 1.2447 - val_sparse_categorical_accuracy: 0.5650
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 2.0827 - sparse_categorical_accuracy: 0.2469 - val_loss: 1.8562 - val_sparse_categorical_accuracy: 0.3324
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.8147 - sparse_categorical_accuracy: 0.3545 - val_loss: 1.7594 - val_sparse_categorical_accuracy: 0.3776
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 1.7447 - sparse_categorical_accuracy: 0.3823 - val_loss: 1.7235 - val_sparse_categorical_accuracy: 0.3867
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 1.6953 - sparse_categorical_accuracy: 0.4063 - val_loss: 1.6569 - val_sparse_categorical_accuracy: 0.4146
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 1.6446 - sparse_categorical_accuracy: 0.4252 - val_loss: 1.6253 - val_sparse_categorical_accuracy: 0.4239
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 1.6153 - sparse_categorical_accuracy: 0.4347 - val_loss: 1.6438 - val_sparse_categorical_accuracy: 0.4135
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 1.5877 - sparse_categorical_accuracy: 0.4394 - val_loss: 1.5851 - val_sparse_categorical_accuracy: 0.4421
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 1.5585 - sparse_categorical_accuracy: 0.4545 - val_loss: 1.6164 - val_sparse_categorical_accuracy: 0.4247
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 1.5379 - sparse_categorical_accuracy: 0.4577 - val_loss: 1.5551 - val_sparse_categorical_accuracy: 0.4534
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 1.5109 - sparse_categorical_accuracy: 0.4650 - val_loss: 1.5475 - val_sparse_categorical_accuracy: 0.4524
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - loss: 2.1735 - sparse_categorical_accuracy: 0.1986 - val_loss: 1.9012 - val_sparse_categorical_accuracy: 0.3260
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - loss: 1.8664 - sparse_categorical_accuracy: 0.3414 - val_loss: 1.7786 - val_sparse_categorical_accuracy: 0.3632
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - loss: 1.7291 - sparse_categorical_accuracy: 0.3935 - val_loss: 1.6267 - val_sparse_categorical_accuracy: 0.4283
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 36ms/step - loss: 1.6167 - sparse_categorical_accuracy: 0.4356 - val_loss: 1.6031 - val_sparse_categorical_accuracy: 0.4197
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - loss: 1.5397 - sparse_categorical_accuracy: 0.4551 - val_loss: 1.5229 - val_sparse_categorical_accuracy: 0.4544
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - loss: 1.4786 - sparse_categorical_accuracy: 0.4758 - val_loss: 1.4472 - val_sparse_categorical_accuracy: 0.4914
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - loss: 1.4338 - sparse_categorical_accuracy: 0.4898 - val_loss: 1.4230 - val_sparse_categorical_accuracy: 0.4940
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - loss: 1.4119 - sparse_categorical_accuracy: 0.5006 - val_loss: 1.4172 - val_sparse_categorical_accuracy: 0.4960
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - loss: 1.3802 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.3992 - val_sparse_categorical_accuracy: 0.5011
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - loss: 1.3537 - sparse_categorical_accuracy: 0.5228 - val_loss: 1.3714 - val_sparse_categorical_accuracy: 0.5112
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 2.1271 - sparse_categorical_accuracy: 0.2263 - val_loss: 1.9745 - val_sparse_categorical_accuracy: 0.2992
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.8978 - sparse_categorical_accuracy: 0.3294 - val_loss: 1.8551 - val_sparse_categorical_accuracy: 0.3475
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 1.8128 - sparse_categorical_accuracy: 0.3615 - val_loss: 1.7866 - val_sparse_categorical_accuracy: 0.3690
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 1.7654 - sparse_categorical_accuracy: 0.3814 - val_loss: 1.7359 - val_sparse_categorical_accuracy: 0.3881
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 1.7191 - sparse_categorical_accuracy: 0.3922 - val_loss: 1.8375 - val_sparse_categorical_accuracy: 0.3481
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.6977 - sparse_categorical_accuracy: 0.4028 - val_loss: 1.7172 - val_sparse_categorical_accuracy: 0.3846
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 1.6686 - sparse_categorical_accuracy: 0.4139 - val_loss: 1.6714 - val_sparse_categorical_accuracy: 0.4044
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 1.6357 - sparse_categorical_accuracy: 0.4266 - val_loss: 1.6521 - val_sparse_categorical_accuracy: 0.4125
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.6271 - sparse_categorical_accuracy: 0.4274 - val_loss: 1.6309 - val_sparse_categorical_accuracy: 0.4215
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 1.6114 - sparse_categorical_accuracy: 0.4358 - val_loss: 1.6296 - val_sparse_categorical_accuracy: 0.4111
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 59ms/step - loss: 2.2154 - sparse_categorical_accuracy: 0.1798 - val_loss: 2.0416 - val_sparse_categorical_accuracy: 0.2703
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 58ms/step - loss: 1.9838 - sparse_categorical_accuracy: 0.2963 - val_loss: 1.9207 - val_sparse_categorical_accuracy: 0.3069
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - loss: 1.8751 - sparse_categorical_accuracy: 0.3393 - val_loss: 1.9661 - val_sparse_categorical_accuracy: 0.2977
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - loss: 1.8215 - sparse_categorical_accuracy: 0.3617 - val_loss: 1.7834 - val_sparse_categorical_accuracy: 0.3706
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 57ms/step - loss: 1.7709 - sparse_categorical_accuracy: 0.3807 - val_loss: 1.7283 - val_sparse_categorical_accuracy: 0.3923
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 58ms/step - loss: 1.7235 - sparse_categorical_accuracy: 0.3954 - val_loss: 1.6915 - val_sparse_categorical_accuracy: 0.3976
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 63ms/step - loss: 1.6648 - sparse_categorical_accuracy: 0.4184 - val_loss: 1.7180 - val_sparse_categorical_accuracy: 0.3858
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 57ms/step - loss: 1.6204 - sparse_categorical_accuracy: 0.4296 - val_loss: 1.6382 - val_sparse_categorical_accuracy: 0.4077
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 57ms/step - loss: 1.5880 - sparse_categorical_accuracy: 0.4379 - val_loss: 1.6078 - val_sparse_categorical_accuracy: 0.4297
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - loss: 1.5379 - sparse_categorical_accuracy: 0.4566 - val_loss: 1.5325 - val_sparse_categorical_accuracy: 0.4506

# %%
# Вывод результатов
print(re_df)
# Out:
#    Batch Size   Model Name  Test Loss  Test Accuracy
# 0          16  Dense Model   1.493945         0.4679
# 1          16    CNN Model   1.146312         0.6041
# 2          32  Dense Model   1.464606         0.4774
# 3          32    CNN Model   1.245875         0.5611
# 4          64  Dense Model   1.540139         0.4617
# 5          64    CNN Model   1.363254         0.5137
# 6         128  Dense Model   1.622541         0.4224
# 7         128    CNN Model   1.527461         0.4542

# %% [markdown]
# Для Dense, и для CNN-моделей видна общая тенденция снижения точности с увеличением размера батча.
# Для CNN модели начальная точность для батча 16 достаточно высока и даже превышает 55%. Возможно, на этом размерности обучалка сохранила общий эффект градиентного спуска, что привело к более высокой производительности.

# %% [markdown]
# **Задание 1.6 (опционально)** Попробуйте найти такую комбинацию метода обучения и нормализации, при которой сеть имеет наилучшую кривую обучения. Поясните, что вы понимаете под "наилучшей" кривой обучения.

# %%
def plot_learning_curves(history, model_description):
    plt.figure(figsize=(12, 4))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['sparse_categorical_accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_sparse_categorical_accuracy'], label='Validation Accuracy')
    plt.title(f'{model_description} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{model_description} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %%
from tensorflow.keras import layers, models

def create_model(optimizer='adam', normalization='batch'):
    model = models.Sequential()

    # Используем InputLayer для определения формы входных данных
    model.add(layers.Input(shape=(32, 32, 3)))  # размер изображений

    model.add(layers.Conv2D(32, (3, 3), activation='relu'))
    if normalization == 'batch':
        model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    if normalization == 'batch':
        model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))

    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    return model

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.callbacks import EarlyStopping

# Параметры для обучения
batch_size = 64
epochs = 10

# Функция для обучения модели
def train_model(optimizer, normalization):
    model = create_model(optimizer=optimizer, normalization=normalization)

    # Установка обратного вызова для EarlyStopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=3)

    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_split=0.2,
                        callbacks=[early_stopping],
                        verbose=0)  # Меньше вывода во время обучения

    return history

# Пример обучения с Adam и Batch Normalization
history = train_model(optimizer='adam', normalization='batch')

# %%
plot_learning_curves(history, "Adam + Batch Normalization")

# Обучение и построение графиков для других комбинаций
history_sgd_bn = train_model(optimizer='sgd', normalization='batch')
plot_learning_curves(history_sgd_bn, "SGD + Batch Normalization")

history_adam_ln = train_model(optimizer='adam', normalization='layer')
plot_learning_curves(history_adam_ln, "Adam + Layer Normalization")

history_sgd_gn = train_model(optimizer='sgd', normalization='group')
plot_learning_curves(history_sgd_gn, "SGD + Group Normalization")

# %% [markdown]
# Пример обучения с "SGD + Group Normalization" демонстриет стремление к максимальной обучающей и валидационной точности.

# %% [markdown]
# Характеристики "наилучшей" кривой обучения:
#
# 1. Сходимость к высокой точности: Наилучшие кривые обучения демонстрируют стремление к максимальной обучающей и валидационной точности.
#
# 2. Минимизация потерь: Наилучшие кривые обучения показывают стремление к снижению значений потери (loss) на тренировочном и валидационном уровнях. Потеря должна снижаться по мере увеличения числа эпох, что указывает на то, что модель обучается и улучшает свои параметры.
#
# 3. Отсутствие переобучения: Наилучшие кривые должны отображать равномерное снижение потерь для обучающего и валидационного наборов, без значительных расхождений.
#
# 4. Стабильность и плавность: Идеальная кривая должна быть плавной и без резких колебаний, что указывает на устойчивое общее поведение модели. Небольшие колебания могут встречаться, особенно в ранних эпохах, но они не должны быть слишком сильными.
#
# 5. Достижение плато: Кривые обучения должны показывать достижение плато — состояние, когда дальнейшее обучение не приводит к значительным улучшениям. Это может указывать на то, что модель достигла пика производительности.
#
# 6. Влияние нормализации и оптимизации: Разные методики нормализации и оптимизации могут оказывать выраженное влияние на кривые обучения. Например, использование Batch Normalization может ускорить сходимость и улучшить общую производительность модели.

# %% [markdown]
# ## Свёрточная нейросеть здорового человека
#
# **Задание 1.7 (обязательно попытаться)** Наигравшись выше, обучим большую свёрточную сеть, которая даст на тестовой выборке __accuracy больше 80%__. В этом задании вам потребуется провести эксперименты, сравнив их между собой в конце. Возможно, может быть несколько проще, если писать выводы во время или сразу после каждого эксперимента, после чего сделать общие выводы.
#
# Рекомендуем начать с лучшей модели предыдущего задания и постепенно её улучшать. Вы можете использовать всё, что угодно: любые активации, сколь угодно большие свёрточные слои и глубокие сети. Единственное ограничение: __нельзя использовать предобученные сети и дополнительные данные__.
#
# ### Полезные советы
# * Для начала, неплохо бы научить что-нибудь побольше, чем 10 фильтров 3x3.
# * __Главное правило: одно изменение на эксперимент__. Если у вас есть 2 идеи по улучшению сети, сначала попробуйте их независимо. Может оказаться, что одно из них дало __+10%__ точности а другое __-7%__. А вы так и будете думать, что сделали 2 полезных изменения которые в сумме дают __+3%__. Если какая-то идея не работает — даже если она вам нравится - опишите ее и выкидывайте из дальнейших экспериментов.
# * __Be careful or you will dropout__. Дропаут (`L.Dropout`) может позволить вам обучить в несколько раз бОльшую сеть без переобучения, выжав несколько процентов качества. Это круто, но не стоит сразу ставить dropout 50%. Во-первых, слишком сильный дропаут только ухудшит сеть (underfitting). Во-вторых, даже если дропаут улучшает качество, он замедляет обучение. Рекомендуем начинать с небольшого дропаута, быстро провести основные эксперименты, а потом жахнуть в 2 раза больше нейронов и дропаута ~~на ночь~~.
# * __Аугментация данных__. Если котика слегка повернуть и подрезать (простите), он всё равно останется котиком. А в керасе есть [удобный класс](https://keras.io/preprocessing/image/), который поставит подрезание котиков на поток. Ещё можно сделать этот трюк в тесте: вертим картинку 10 раз, предсказываем вероятности и усредняем. Только один совет: прежде, чем учить, посмотрите глазами на аугментированные картинки. Если вы сами не можете их различить, то и сеть не сможет.
# * __Don't just stack more layers__. Есть более эффективные способы организовать слои, чем простой Sequential. Вот пара идей: [Inception family](https://hacktilldawn.com/2016/09/25/inception-modules-explained-and-implemented/), [ResNet family](https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035?gi=9018057983ca), [Densely-connected convolutions](https://arxiv.org/abs/1608.06993). Только не копируйте архитектуру подчистую — вам скорее всего хватит меньшего размера.
# * __Долго != плохо__. Более глубокие архитектуры обычно требуют бОльше эпох до сходимости. Это значит, что в первые несколько эпох они могут быть хуже менее глубоких аналогов. Дайте им время, запаситесь чаем и обмажьтесь batch-norm-ом.

# %% [markdown]
# Создание базовой свёрточной модели:

# %%
from tensorflow.keras import layers, models

def create_base_cnn_model():
    model = models.Sequential()
    model.add(layers.Input(shape=(32, 32, 3)))

    # Свёрточные слои
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(256, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Flatten())

    # Полносвязные слои
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))  # Dropout для предотвращения переобучения
    model.add(layers.Dense(10, activation='softmax'))

    # Компиляция модели
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    return model

# %% [markdown]
# Обучение и оценка модели

# %%
model = create_base_cnn_model()
early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)

history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=50,
                    batch_size=64,
                    callbacks=[early_stopping],
                    verbose=1)

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 222s 352ms/step - loss: 1.8733 - sparse_categorical_accuracy: 0.3895 - val_loss: 1.4287 - val_sparse_categorical_accuracy: 0.4894
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 259s 347ms/step - loss: 1.1368 - sparse_categorical_accuracy: 0.6029 - val_loss: 1.0286 - val_sparse_categorical_accuracy: 0.6438
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 263s 349ms/step - loss: 0.9219 - sparse_categorical_accuracy: 0.6811 - val_loss: 1.1246 - val_sparse_categorical_accuracy: 0.6057
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 260s 345ms/step - loss: 0.8010 - sparse_categorical_accuracy: 0.7208 - val_loss: 0.8765 - val_sparse_categorical_accuracy: 0.6989
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 265s 350ms/step - loss: 0.6743 - sparse_categorical_accuracy: 0.7616 - val_loss: 1.3512 - val_sparse_categorical_accuracy: 0.5872
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 263s 351ms/step - loss: 0.5904 - sparse_categorical_accuracy: 0.7937 - val_loss: 0.9959 - val_sparse_categorical_accuracy: 0.6837
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 260s 348ms/step - loss: 0.5001 - sparse_categorical_accuracy: 0.8260 - val_loss: 0.9345 - val_sparse_categorical_accuracy: 0.7148
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 261s 347ms/step - loss: 0.4446 - sparse_categorical_accuracy: 0.8451 - val_loss: 0.9996 - val_sparse_categorical_accuracy: 0.7064
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 264s 351ms/step - loss: 0.3680 - sparse_categorical_accuracy: 0.8684 - val_loss: 1.1842 - val_sparse_categorical_accuracy: 0.6873
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 263s 352ms/step - loss: 0.3241 - sparse_categorical_accuracy: 0.8864 - val_loss: 0.9316 - val_sparse_categorical_accuracy: 0.7266
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 261s 350ms/step - loss: 0.2816 - sparse_categorical_accuracy: 0.9005 - val_loss: 0.8926 - val_sparse_categorical_accuracy: 0.7446
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 261s 349ms/step - loss: 0.2491 - sparse_categorical_accuracy: 0.9137 - val_loss: 1.1434 - val_sparse_categorical_accuracy: 0.7283
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 256s 339ms/step - loss: 0.2274 - sparse_categorical_accuracy: 0.9190 - val_loss: 1.1001 - val_sparse_categorical_accuracy: 0.7255
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 264s 343ms/step - loss: 0.2073 - sparse_categorical_accuracy: 0.9301 - val_loss: 1.2122 - val_sparse_categorical_accuracy: 0.7073
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 261s 340ms/step - loss: 0.1936 - sparse_categorical_accuracy: 0.9337 - val_loss: 1.0898 - val_sparse_categorical_accuracy: 0.7498
# Epoch 16/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 213s 341ms/step - loss: 0.1769 - sparse_categorical_accuracy: 0.9408 - val_loss: 1.5692 - val_sparse_categorical_accuracy: 0.6711
# Epoch 17/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 258s 336ms/step - loss: 0.1483 - sparse_categorical_accuracy: 0.9484 - val_loss: 1.2592 - val_sparse_categorical_accuracy: 0.7356
# Epoch 18/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 261s 335ms/step - loss: 0.1593 - sparse_categorical_accuracy: 0.9464 - val_loss: 1.1625 - val_sparse_categorical_accuracy: 0.7557
# Epoch 19/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 213s 341ms/step - loss: 0.1317 - sparse_categorical_accuracy: 0.9539 - val_loss: 1.2835 - val_sparse_categorical_accuracy: 0.7434
# Epoch 20/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 260s 338ms/step - loss: 0.1496 - sparse_categorical_accuracy: 0.9497 - val_loss: 1.3761 - val_sparse_categorical_accuracy: 0.7431
# Epoch 21/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 260s 334ms/step - loss: 0.1341 - sparse_categorical_accuracy: 0.9559 - val_loss: 1.5442 - val_sparse_categorical_accuracy: 0.7199
# Epoch 22/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 263s 336ms/step - loss: 0.1238 - sparse_categorical_accuracy: 0.9591 - val_loss: 1.8283 - val_sparse_categorical_accuracy: 0.6948
# Epoch 23/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 261s 334ms/step - loss: 0.1206 - sparse_categorical_accuracy: 0.9603 - val_loss: 1.4278 - val_sparse_categorical_accuracy: 0.7545
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - loss: 1.1236 - sparse_categorical_accuracy: 0.7600
# Test Loss: 1.1645748615264893, Test Accuracy: 0.7530999779701233

# %% [markdown]
# Момент истины: проверьте, какого качества достигла ваша сеть.

# %%
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# Test Loss: 1.1645748615264893, Test Accuracy: 0.7530999779701233

# %% [markdown]
# А теперь, опишите свои <s>ощущения</s> результаты от проведенных экспериментов.

# %% [markdown]
# Проведённый эксперимент с базовой свёрточной нейросетью привел к следующему результату:
# - Потеря на тестовой выборке (Test Loss): 1.16
# - Точность на тестовой выборке (Test Accuracy): 75.3%
#
# Это значение ниже целевого порога в 80%. Несмотря на наличие нескольких свёрточных слоев, применения нормализации (BatchNormalization) и дропаута, модель не смогла достичь необходимой точности.
