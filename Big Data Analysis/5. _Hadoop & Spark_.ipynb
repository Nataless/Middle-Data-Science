# %% [markdown]
# ##**Домашнее задание по теме "Hadoop & Spark"**
#
# **Задание:**
#
# 1. Прочитайте об операторах Spark. Пришлите ответы на вопросы.
#
# Какие команды отвечают за:
# - сохранение результата в текстовый файл (это Action или Transformation?);
# - получение первых n-элементов массива (Action или Transformation?);
# - объединение двух RDD в один (Action или Transformation?);
# - в чем разница между Reduce и CoGroup-операторами (Action или Transformation?).
#
# 2. Нарисуйте DAG для Spark для подсчёта количества уникальных слов в файле.

# %% [markdown]
# **Решение:**

# %% [markdown]
# Задание 1.
#
# Какие команды отвечают за:
#
# сохранение результата в текстовый файл (это Action или Transformation?) - Actions
# получение первых n-элементов массива (Action или Transformation?) - Actions
# объединение двух RDD в один (Action или Transformation?) - Transformation
# в чем разница между Reduce и CoGroup-операторами (Action или Transformation?) - Transformation
# Cogroup не нужно сначала объединять данные, чтобы сгруппировать их. Результатом является один и тот же ключ и наборы данных в разных наборах данных. GroupByKey необходимо сначала объединить, а затем сгруппировать в соответствии с одним и тем же ключом.
#
# Задание 2. https://lucid.app/lucidchart/8560f280-4469-4d50-903d-83487626ca8c/edit?viewport_loc=-228%2C-416%2C1962%2C932%2C0_0&invitationId=inv_f12aa2ed-4d03-4afb-8208-db307905aaf0
