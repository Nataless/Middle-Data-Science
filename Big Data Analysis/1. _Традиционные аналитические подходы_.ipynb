# %% [markdown]
# ##**Домашнее задание по теме "Традиционные аналитические подходы"**
#
# **Задание:**
#
# Задание 1. На основе данных о фильмах:
# нарисовать круговую диаграмму с доходами от 5-ти самых прибыльных фильмов за всё время,
# получить топ-5 самых продаваемых фильмов в первом магазине.
#
# Выполнить еще 2 задания на SQL:
# **Задание 2 https://pgexercises.com/questions/basic/where.html,**
# **Задание 3 https://pgexercises.com/questions/basic/where2.html.**
# В качестве решения пришлите в личном кабинете:
#
# ссылку на расшаренный Google Spreadsheet,
# скриншоты выполненных PGExercises.

# %% [markdown]
# **Решение:**

# %% [markdown]
# Задание 1. https://docs.google.com/spreadsheets/d/1VvEq4uGPXXMk6Oz41iGk5cf1RHE7dbCLhEv81NVo2A8/edit?usp=sharing

# %% [markdown]
# Задание 2. ![Задание 2.png](data:image/png;base64,...)

# %% [markdown]
# Задание 3. ![Задание 3.png](data:image/png;base64,...)
